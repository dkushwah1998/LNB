# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = np.random.randn(100)
data
# Out:
# array([ 0.74485733,  0.32985166, -1.3210867 ,  0.09860482,  0.60586325,
#        -0.86652111,  0.27098181, -0.05352251, -1.96805818, -2.47675415,
#        -0.12923986,  0.33581162, -0.59386101, -0.3135143 , -1.01260383,
#         0.50024638, -0.0136478 ,  0.65422608, -0.22362254,  0.38904498,
#        -1.17177504, -1.03375668,  0.65338967,  0.94535284,  0.76472223,
#        -0.72702808, -0.40314856,  0.15142362, -2.15164686, -0.42772673,
#        -0.60751032,  0.21133055, -0.34142961,  1.12060307, -0.15288054,
#        -0.22506507, -0.57989813, -1.51261775,  0.30572169, -0.64039725,
#         1.54743896,  0.71974615, -0.37196641, -0.45205698,  1.11775654,
#        -1.17401834, -0.21552563, -1.33255076,  1.0233863 , -2.23652409,
#         0.25869838, -0.64458406,  1.03323973,  0.08971713,  0.33388963,
#         1.36718646,  0.25759869,  0.89590946,  1.83759672,  0.27645537,
#        -0.90146192, -2.4338406 , -0.10666788, -1.04362687, -2.24003619,
# ...

# %%
plt.hist(data)
plt.show()

# %%
age = np.random.randint(12,80,50)

# %%
plt.hist(age,bins = [10,20,30,40,50,60,70,80])
plt.show()

# %%
age1 = [12,18,30,32,76,35,46,48,51]
rev = [10.5,22.8,42,33.2,6,21,4,20,23]

plt.scatter(age1,rev)
plt.show()
