# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\Data-LB\New folder\diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.describe(include = [int],percentiles = [0.3,0.5,0.7]).T
# Out:
#                count        mean         std   min    30%    50%    70%    max
# Pregnancies    768.0    3.845052    3.369578   0.0    1.0    3.0    5.0   17.0
# Glucose        768.0  120.894531   31.972618   0.0  102.0  117.0  134.0  199.0
# BloodPressure  768.0   69.105469   19.355807   0.0   64.0   72.0   78.0  122.0
# SkinThickness  768.0   20.536458   15.952218   0.0    8.2   23.0   31.0   99.0
# Insulin        768.0   79.799479  115.244002   0.0    0.0   30.5  106.0  846.0
# Age            768.0   33.240885   11.760232  21.0   25.0   29.0   38.0   81.0
# Outcome        768.0    0.348958    0.476951   0.0    0.0    0.0    1.0    1.0

# %%
df[df.duplicated()].count()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df['BMI'].describe().T
# Out:
# count    768.000000
# mean      31.992578
# std        7.884160
# min        0.000000
# 25%       27.300000
# 50%       32.000000
# 75%       36.600000
# max       67.100000
# Name: BMI, dtype: float64

# %%
df[df.isnull()].count()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df2 = df.copy()

# %%
df2.loc[2:5,('Glucose','BMI')] = None

# %%
df2.shape
# Out:
# (768, 9)

# %%
df2.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     4
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         4
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df2.isnull().sum().sum()
# Out:
# 8

# %%
df2.dropna().shape
# Out:
# (764, 9)

# %%
df2.iloc[1:5,2:3]
# Out:
#    BloodPressure
# 1             66
# 2             64
# 3             66
# 4             40

# %%
mean_gl = df2['Glucose'].mean()

# %%
df2['Glucose'].fillna(mean_gl, inplace =True)

# %%
df2
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6  148.000000             72             35        0  33.6
# 1              1   85.000000             66             29        0  26.6
# 2              8  120.840314             64              0        0   NaN
# 3              1  120.840314             66             23       94   NaN
# 4              0  120.840314             40             35      168   NaN
# ..           ...         ...            ...            ...      ...   ...
# 763           10  101.000000             76             48      180  32.9
# 764            2  122.000000             70             27        0  36.8
# 765            5  121.000000             72             23      112  26.2
# 766            1  126.000000             60              0        0  30.1
# 767            1   93.000000             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df2['BMI'].fillna(df2['BMI'].median(),inplace = True)

# %%
df2
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6  148.000000             72             35        0  33.6
# 1              1   85.000000             66             29        0  26.6
# 2              8  120.840314             64              0        0  32.0
# 3              1  120.840314             66             23       94  32.0
# 4              0  120.840314             40             35      168  32.0
# ..           ...         ...            ...            ...      ...   ...
# 763           10  101.000000             76             48      180  32.9
# 764            2  122.000000             70             27        0  36.8
# 765            5  121.000000             72             23      112  26.2
# 766            1  126.000000             60              0        0  30.1
# 767            1   93.000000             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df3= pd.concat([df,df])

# %%
df3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df3.drop_duplicates()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.columns = [col.lower() for col in df]

# %%
df
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      diabetespedigreefunction  age  outcome
# 0                       0.627   50        1
# ...

# %%
df.loc[2:3]
# Out:
#    pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
#
#    diabetespedigreefunction  age  outcome
# 2                     0.672   32        1
# 3                     0.167   21        0

# %%
df.iloc[2:5]
# Out:
#    pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    diabetespedigreefunction  age  outcome
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df[df['bmi']>30 ]
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0              6      148             72             35        0  33.6
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 761            9      170             74             31        0  44.0
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      diabetespedigreefunction  age  outcome
# 0                       0.627   50        1
# ...
