# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\New folder\Accenture-Data-Analytics-Virtual-Program-Answers-main\Task 2 - ModelAnswerFullDataset.csv", index_col = 0)

# %%
df
# Out:
#                                  Content ID Reaction Type  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
# ...                                     ...           ...
# 24568  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike
# 24569  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued
# 24570  75d6b589-7fae-4a6d-b0d0-752845150e56    interested
# 24571  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 24572  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish
#
#                   Datetime                               User ID Content Type  \
# 0      2020-11-07 09:43:50  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo
# 1      2021-06-17 12:22:51  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo
# ...

# %%
df.head()
# Out:
#                              Content ID Reaction Type             Datetime  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2020-11-07 09:43:50
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  2021-06-17 12:22:51
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared  2021-04-18 05:13:58
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2021-01-06 19:13:01
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested  2020-08-23 12:25:58
#
#                                 User ID Content Type  Category Sentiment  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  studying  negative
# 1  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  studying  negative
# 2  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  studying  negative
# 3  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  studying  negative
# 4  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  studying  positive
#
#    Score
# 0      0
# 1     10
# 2     15
# 3      0
# 4     30

# %%
df.tail()
# Out:
#                                  Content ID Reaction Type  \
# 24568  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike
# 24569  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued
# 24570  75d6b589-7fae-4a6d-b0d0-752845150e56    interested
# 24571  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 24572  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish
#
#                   Datetime                               User ID Content Type  \
# 24568  2020-06-27 09:46:48  b8c653b5-0118-4d7e-9bde-07c2de90f0ff        audio
# 24569  2021-02-16 17:17:02  b8c653b5-0118-4d7e-9bde-07c2de90f0ff        audio
# 24570  2020-09-12 03:54:58  b8c653b5-0118-4d7e-9bde-07c2de90f0ff        audio
# 24571  2020-11-04 20:08:31  b8c653b5-0118-4d7e-9bde-07c2de90f0ff        audio
# 24572  2021-01-04 04:55:11  b8c653b5-0118-4d7e-9bde-07c2de90f0ff        audio
#
#          Category Sentiment  Score
# 24568  technology  negative     10
# 24569  technology  positive     45
# 24570  technology  positive     30
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24573 entries, 0 to 24572
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Content ID     24573 non-null  object
#  1   Reaction Type  24573 non-null  object
#  2   Datetime       24573 non-null  object
#  3   User ID        24573 non-null  object
#  4   Content Type   24573 non-null  object
#  5   Category       24573 non-null  object
#  6   Sentiment      24573 non-null  object
#  7   Score          24573 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 1.7+ MB

# %%
temp_df = df.append(df)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1616\2067459577.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_df = df.append(df)

# %%
temp_df
# Out:
#                                  Content ID Reaction Type  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
# ...                                     ...           ...
# 24568  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike
# 24569  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued
# 24570  75d6b589-7fae-4a6d-b0d0-752845150e56    interested
# 24571  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 24572  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish
#
#                   Datetime                               User ID Content Type  \
# 0      2020-11-07 09:43:50  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo
# 1      2021-06-17 12:22:51  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo
# ...

# %%
temp_df.drop_duplicates()
# Out:
#                                  Content ID Reaction Type  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
# ...                                     ...           ...
# 24568  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike
# 24569  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued
# 24570  75d6b589-7fae-4a6d-b0d0-752845150e56    interested
# 24571  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 24572  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish
#
#                   Datetime                               User ID Content Type  \
# 0      2020-11-07 09:43:50  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo
# 1      2021-06-17 12:22:51  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo
# ...

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49146 entries, 0 to 24572
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Content ID     49146 non-null  object
#  1   Reaction Type  49146 non-null  object
#  2   Datetime       49146 non-null  object
#  3   User ID        49146 non-null  object
#  4   Content Type   49146 non-null  object
#  5   Category       49146 non-null  object
#  6   Sentiment      49146 non-null  object
#  7   Score          49146 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 3.4+ MB

# %%
temp_df.drop_duplicates(inplace = True)

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24573 entries, 0 to 24572
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Content ID     24573 non-null  object
#  1   Reaction Type  24573 non-null  object
#  2   Datetime       24573 non-null  object
#  3   User ID        24573 non-null  object
#  4   Content Type   24573 non-null  object
#  5   Category       24573 non-null  object
#  6   Sentiment      24573 non-null  object
#  7   Score          24573 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 1.7+ MB

# %%
d = {"A":[3,3,3,3],'B':[8,3,3,3]}

demo = pd.DataFrame(d)
demo
# Out:
#    A  B
# 0  3  8
# 1  3  3
# 2  3  3
# 3  3  3

# %%
demo.drop_duplicates()
# Out:
#    A  B
# 0  3  8
# 1  3  3

# %%
demo.drop_duplicates(keep = 'last')
# Out:
#    A  B
# 0  3  8
# 3  3  3

# %%
demo.drop_duplicates(keep = False)
# Out:
#    A  B
# 0  3  8

# %%
demo.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# dtype: bool

# %%
demo[demo.duplicated()]
# Out:
#    A  B
# 2  3  3
# 3  3  3

# %%
demo[demo.duplicated()].count()
# Out:
# A    2
# B    2
# dtype: int64

# %%
demo[demo.duplicated()]['A']
# Out:
# 2    3
# 3    3
# Name: A, dtype: int64

# %%
demo[demo.duplicated()]['B']
# Out:
# 2    3
# 3    3
# Name: B, dtype: int64

# %%
demo2 = demo.pivot_table(index=['A'],aggfunc = 'size')

# %%
demo2
# Out:
# A
# 3    4
# dtype: int64

# %%
demo.drop_duplicates(subset = ['B'])
# Out:
#    A  B
# 0  3  8
# 1  3  3

# %%
demo.drop_duplicates(subset = ['A'])
# Out:
#    A  B
# 0  3  8
